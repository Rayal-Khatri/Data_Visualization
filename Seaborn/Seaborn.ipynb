# %% [markdown]
# # Dependencies

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np
from sklearn.datasets import load_breast_cancer
cancer = load_breast_cancer()
tips_df = sns.load_dataset("tips")
titanic_df = sns.load_dataset('titanic')
global_df = pd.read_csv('Who_is_responsible_for_global_warming.csv')

# %% [markdown]
# # Line Plot

# %%
days = list(range(1, 16))

ktm_tempe = [22.5, 23.0, 21.5, 20.0, 19.5, 18.0, 17.5, 
               18.5, 19.0, 20.0, 21.0, 22.0, 23.0, 24.0, 25.0]

lal_temp = [21.5, 22.0, 22.8, 23.5, 24.0, 24.5, 25.0, 25.5, 26.0, 26.5, 27.0, 27.5, 28.0, 28.5, 29.0]

temp_df = pd.DataFrame({'days':days,'ktm_tempe':ktm_tempe})

sns.lineplot(
    x= 'days',
    y='ktm_tempe',
    data= temp_df,
)
plt.show()

# %%
sns.set(style="darkgrid")

plt.figure(figsize=(16,9))
sns.lineplot(
    y='total_bill',
    x = 'size',
    data= tips_df,
    hue='sex',
    style='sex',
    markers=['o','^'],
    legend= 'full',
)
plt.xlabel("Size", fontsize = 15),
plt.ylabel("Total Bill", fontsize = 15),
plt.legend(loc='upper left')
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.lineplot(
    x = 'total_bill',
    y='size',
    data= tips_df,
)
plt.show()

# %%
plt.figure(figsize=(16,9))
sns.lineplot(
    x = 'total_bill',
    y='tip',
    data= tips_df,
)
plt.show()

# %%
sns.set(style="darkgrid")
tips_df = sns.load_dataset("tips")
plt.figure(figsize=(16,9))
sns.lineplot(
    y='total_bill',
    x = 'size',
    data= tips_df,
    hue='day',
    style='day',
    markers=['o','^','>','<'],
    legend= 'full',
)
plt.xlabel("Size", fontsize = 15),
plt.ylabel("Total Bill", fontsize = 15),
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
sns.histplot(tips_df['size'])

plt.subplot(2, 2, 2)
sns.histplot(tips_df['tip'])

plt.subplot(2, 2, 3)
sns.histplot(tips_df['total_bill'])

plt.subplot(2, 2, 4)
plt.pie([1])

plt.tight_layout()
plt.show()

# %%
sns.displot(
        tips_df["total_bill"],
        bins = 10,
        kde = True,
        rug= True,
        color='r',
        label = "Total Bill",
    )

plt.legend()
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(16,9))
sns.set()

tips_df.total_bill.sort_values()

bins = [0,5,10,15,20,25,30,35,40,45,50,55]

sns.histplot(
                tips_df['total_bill'],
                bins = bins,
                kde = True,
                line_kws= {
                    'color' : '#DC143C'
                }
             )


plt.xticks(bins)

plt.title("Histogram of Total BIll")
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Barplot/ Bar Graph

# %%
order = ['Sun', 'Thur', 'Fri','Sat']
kwargs = {
        'alpha': 0.9, 
        'linestyle' : '--',
        'linewidth' : 2,
        "edgecolor" : 'k',
    }


sns.barplot(
    # x = tips_df.day,     
    x= 'day',
    y = 'total_bill',
    hue= 'sex',
    data = tips_df,
    order= order,
    hue_order=['Female',"Male"],
    estimator= np.max,
    # errorbar=('ci', 100),
    n_boot= 2,
    saturation= 10,
    **kwargs
)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(16,9))
sns.barplot(
    x= 'day',
    y = 'total_bill',
    hue= 'sex',
    data = tips_df,
    order= order,
    hue_order=['Female',"Male"],
    # n_boot= 2,
    saturation= 10,
    **kwargs
    )


plt.title ("Tips DataFrame")
plt.xlabel('Days')
plt.ylabel('Total Bill'),    
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
plt.figure(figsize=(16,9))
plt.axis([0,80,0,300]) 
sns.scatterplot(
    x = 'age',
    y = 'fare',
    hue='sex',
    data= titanic_df,
    style= 'who',
    # size= 'who',
    # sizes = (100,400)
    
)
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# plt.figure(figsize=(5,5))
# plt.axis([0,80,0,300]) 
sns.scatterplot(
    x = 'who',
    y = 'fare',
    hue='alive',
    data= titanic_df,
    style= 'alive',
    # size= 'who',
    # sizes = (100,400)
    
)
# Out:
# <Axes: xlabel='who', ylabel='fare'>

# %% [markdown]
# # Heatmap

# %%
arr_2D = np.linspace(1,5,12).reshape(4,3)

# %%
sns.heatmap(arr_2D)
# Out:
# <Axes: >

# %%
global_df = global_df.drop(columns=["Country Code", "Indicator Name", "Indicator Code"],axis=1).set_index("Country Name")
global_df.head(6)
# Out:
#                          2000       2001       2002       2003       2004  \
# Country Name
# United States       20.178751  19.636505  19.613404  19.564105  19.658371
# United Kingdom       9.199549   9.233175   8.904123   9.053278   8.989140
# India                0.979870   0.971698   0.967381   0.992392   1.025028
# China                2.696862   2.742121   3.007083   3.524074   4.037991
# Russian Federation  10.627121  10.669603  10.715901  11.090647  11.120627
# Australia           17.200610  16.733367  17.370452  16.901959  17.026515
#
#                          2005       2006       2007       2008       2009  \
# Country Name
# United States       19.591885  19.094067  19.217898  18.461764  17.157738
# United Kingdom       8.982939   8.898710   8.617164   8.424424   7.574622
# India                1.068563   1.121982   1.193210   1.310098   1.431844
# China                4.523178   4.980314   5.334910   5.701915   6.010102
# ...

# %%
plt.figure(figsize=(16,9))
annot_kws = {
    'fontsize' : 10,
    'fontstyle' :'italic',
    'color' : 'k',
    'alpha' : .9,
    'verticalalignment' : 'center',
    'backgroundcolor' : 'w',
}

cbar_kws = {"orientation": "horizontal",
"shrink":1,
'extend': 'min',
'extendfrac': 0.1,
"ticks":np.arange(0,22),
"drawedges": True,}

sns.heatmap(
        global_df,
        vmin= 0,
        vmax= 21,
        cmap='cool',
        annot=True,
        annot_kws= annot_kws,
        linewidths= 2,
        linecolor= 'k',
        # cbar=False,   #To make the temperature bae disappear
        cbar_kws= cbar_kws
    )
# Out:
# <Axes: ylabel='Country Name'>

# %% [markdown]
# # Showing Correlation

# %%
plt.figure(figsize=(16,9))
ax = sns.heatmap(
        global_df.corr(),
        annot = True,
        linewidths=.5,
    )

ax.tick_params(
    size = 10,
    color = 'w',
    labelsize = 10,
    labelcolor = 'k'
)

plt.title("Global warming Countries", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Global warming Countries')

# %%
cancer_df = pd.DataFrame(
    np.c_[cancer['data'], cancer['target']],
    columns=np.append(cancer['feature_names'], 'target')
)

# %%
plt.figure(figsize=(25,15))
sns.heatmap(
    cancer_df.corr(),
    annot= True,
    linewidths= 3
)
ax.tick_params(
    size = 10,
    color = 'w',
    labelsize = 10,
    labelcolor = 'k'
)

plt.title("Brest Cancer Patients", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Brest Cancer Patients')
